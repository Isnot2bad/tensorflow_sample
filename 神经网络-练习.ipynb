# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
#载入数据集
mnist=input_data.read_data_sets("MNIST_data",one_hot=True)

#定义批次大小 每次训练放入图片数量
batch_size=100
#计算一共多少个批次 (图片数量除以（//)批次大小）
n_batch=mnist.train.num_examples // batch_size

#定义命名空间

with tf.name_scope('input'):

#定义两个placeholder
    x=tf.placeholder(tf.float32,[None,784],name='x_input')
    y=tf.placeholder(tf.float32,[None,10],name='y_input')
    keep_prob=tf.placeholder(tf.float32)
    lr=tf.Variable(0.01,dtype=tf.float32)


#创建神经网络第一层
W1=tf.Variable(tf.truncated_normal([784,500],stddev=0.1))
b1=tf.Variable(tf.zeros([500])+0.1)
L1=tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop=tf.nn.dropout(L1,keep_prob)

#创建神经第二层
W2=tf.Variable(tf.truncated_normal([500,300],stddev=0.1))
b2=tf.Variable(tf.zeros([300])+0.1)
L2=tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop=tf.nn.dropout(L2,keep_prob)

#定义输出层
W3=tf.Variable(tf.truncated_normal([300,10],stddev=0.1))
b3=tf.Variable(tf.zeros([10])+0.1)
prediction=tf.nn.softmax(tf.matmul(L2_drop,W3)+b3)


#定义交叉墒代价函数
loss=tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))

#使用梯度下降法
#train_step=tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#训练
train_step=tf.train.AdamOptimizer(lr).minimize(loss)

#初始化变量

init=tf.global_variables_initializer()

#结果存放在布尔型列表中  定义准确率 比较两个agrmax大小，相同就是TRUE 不同就是FALSE。 argmax求最大值所在位置
correct_prediction=tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))

#求准确率 (tf.cast()将布尔型数据转化成数值型 然后计算准确率)
accuracy=tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    writer=tf.summary.FileWriter('logs/',sess.graph)
    for epoch in range(51):
        #重新赋值学习率，使学习率不断变小 0.01*（0.95的学习次数次方）
        sess.run(tf.assign(lr,0.01*(0.95**epoch)))
        for batch in range(n_batch):
            batch_xs,batch_ys=mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys,keep_prob:1.0})
            
            learning_rate=sess.run(lr)
            
        acc=sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels,keep_prob:1.0})
        print("Iter"+str(epoch)+"Testing Accuracy="+str(acc)+"learning rate="+str(learning_rate))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter0Testing Accuracy=0.9221learning rate=0.01
# Iter1Testing Accuracy=0.9167learning rate=0.0095
# Iter2Testing Accuracy=0.9213learning rate=0.009025
# Iter3Testing Accuracy=0.9262learning rate=0.00857375
# Iter4Testing Accuracy=0.9274learning rate=0.00814506
# Iter5Testing Accuracy=0.9324learning rate=0.00773781
# Iter6Testing Accuracy=0.932learning rate=0.00735092
# Iter7Testing Accuracy=0.9332learning rate=0.00698337
# Iter8Testing Accuracy=0.9318learning rate=0.0066342
# Iter9Testing Accuracy=0.9412learning rate=0.00630249
# Iter10Testing Accuracy=0.9352learning rate=0.00598737
# Iter11Testing Accuracy=0.9344learning rate=0.005688
# Iter12Testing Accuracy=0.9387learning rate=0.0054036
# Iter13Testing Accuracy=0.9434learning rate=0.00513342
# Iter14Testing Accuracy=0.9401learning rate=0.00487675
# Iter15Testing Accuracy=0.9421learning rate=0.00463291
# Iter16Testing Accuracy=0.945learning rate=0.00440127
# Iter17Testing Accuracy=0.945learning rate=0.0041812
# Iter18Testing Accuracy=0.9481learning rate=0.00397214
# Iter19Testing Accuracy=0.9482learning rate=0.00377354
# Iter20Testing Accuracy=0.9533learning rate=0.00358486
# Iter21Testing Accuracy=0.9528learning rate=0.00340562
# Iter22Testing Accuracy=0.9553learning rate=0.00323534
# Iter23Testing Accuracy=0.9559learning rate=0.00307357
# Iter24Testing Accuracy=0.9519learning rate=0.00291989
# Iter25Testing Accuracy=0.9554learning rate=0.0027739
# Iter26Testing Accuracy=0.9567learning rate=0.0026352
# Iter27Testing Accuracy=0.9553learning rate=0.00250344
# Iter28Testing Accuracy=0.9546learning rate=0.00237827
# Iter29Testing Accuracy=0.9579learning rate=0.00225936
# Iter30Testing Accuracy=0.9583learning rate=0.00214639
# Iter31Testing Accuracy=0.9591learning rate=0.00203907
# Iter32Testing Accuracy=0.9598learning rate=0.00193711
# Iter33Testing Accuracy=0.9604learning rate=0.00184026
# Iter34Testing Accuracy=0.96learning rate=0.00174825
# Iter35Testing Accuracy=0.9632learning rate=0.00166083
# Iter36Testing Accuracy=0.9582learning rate=0.00157779
# Iter37Testing Accuracy=0.9636learning rate=0.0014989
# Iter38Testing Accuracy=0.9631learning rate=0.00142396
# Iter39Testing Accuracy=0.9607learning rate=0.00135276
# Iter40Testing Accuracy=0.9641learning rate=0.00128512
# Iter41Testing Accuracy=0.9636learning rate=0.00122087
# Iter42Testing Accuracy=0.9639learning rate=0.00115982
# Iter43Testing Accuracy=0.9631learning rate=0.00110183
# Iter44Testing Accuracy=0.9641learning rate=0.00104674
# Iter45Testing Accuracy=0.9663learning rate=0.000994403
# Iter46Testing Accuracy=0.9649learning rate=0.000944682
# Iter47Testing Accuracy=0.9666learning rate=0.000897448
# Iter48Testing Accuracy=0.968learning rate=0.000852576
# Iter49Testing Accuracy=0.9664learning rate=0.000809947
# Iter50Testing Accuracy=0.9653learning rate=0.00076945
